# %% [markdown]
# # Prepare data form survey

# %% [markdown]
# ## Imports

# %%
# import pandas module 
import pandas as pd

# %% [markdown]
# ## Import Data

# %%
# import header file
df_header = pd.read_excel('data/question_headers.xlsx')  #original
df_header.iloc[0:2, 0:10]
# Out:
#   Respondent ID Collector ID  Start Date  End Date  IP Address Email Address  \
# 0           NaN          NaN         NaN       NaN         NaN           NaN
# 1       resp_id     colle_id  start_date  end_date  ip_address         email
#
#    First Name  Last Name Custom Data 1  \
# 0         NaN        NaN           NaN
# 1  first_name  last_name   custom_data
#
#   Do you grant your consent as set out above?
# 0                                    Response
# 1                                     consent

# %%
# df_header.iloc[1].to_list()

# %%
# import data file into dataframe uplaod
df_upload = pd.read_excel('data/138_quest.xlsx')  
df        = pd.read_excel('data/138_quest.xlsx')  #working
df_upload.head(3)
# Out:
#    Respondent ID  Collector ID          Start Date            End Date  \
# 0            NaN           NaN                 NaT                 NaT
# 1   1.289784e+10   404063954.0 2021-08-17 11:13:06 2021-08-17 12:04:29
# 2   1.289775e+10   404063954.0 2021-08-17 10:31:55 2021-08-17 11:16:20
#
#       IP Address  Email Address  First Name  Last Name  Custom Data 1  \
# 0            NaN            NaN         NaN        NaN            NaN
# 1  160.48.234.77            NaN         NaN        NaN            NaN
# 2  160.48.234.77            NaN         NaN        NaN            NaN
#
#   Do you grant your consent as set out above?  ...  \
# 0                                    Response  ...
# 1                                         Yes  ...
# 2                                         Yes  ...
#
#   From a product owner perspective, is trust an important contributor to adoption of the system?  \
# 0                                           Response
# 1                                     Very important
# 2                                     Very important
#
#   A lack of trust will lead to a lower level of adoption of the system.  \
# 0                                           Response
# 1                                              Agree
# 2                         Neither agree nor disagree
#
#   From a product owner perspective, do you think the transparency of an AI application's logic is important/beneficial for trustworthiness? Transparency is, for example, the explainability of the machine learning decision/predictive process.  \
# 0                                           Response
# 1                                     Very important
# 2                                 Somewhat important
#
#   From a product owner perspective, do you think assigning accountability of a AI application's actions is important/beneficial for trustworthiness? Accountability would be, for example, who is accountable when an autonomous vehicle crashes.  \
# 0                                           Response
# 1                                              Agree
# 2                                              Agree
#
#   From a product owner perspective, do you think the fairness of the AI application's actions is important for trustworthiness. For example, demographic biases in the automation of credit vetting.  \
# 0                                           Response
# 1                                     Very important
# 2                                 Somewhat important
#
#   From a product owner perspective, is trustworthiness an important contributor to the adoption of the system?  \
# 0                                           Response
# 1                                     Very important
# 2                                     Very important
#
#   A lack of trust in the process around an AI system will lead to a lower level of adoption of the AI application.  \
# 0                                           Response
# 1                                              Agree
# 2                                           Disagree
#
#   Organisations need to ensure that the AI applications that they develop are transparent (allow explainability) in their actions.  \
# 0                                           Response
# 1                                              Agree
# 2                                              Agree
#
#   If any, what ethical considerations other than fairness, transparency and accountability should organisations have when they develop AI applications?  \
# 0                                Open-Ended Response
# 1                                                NaN
# 2                                                NaN
#
#   Ensuring that AI applications are fair, accountable and transparent, will lead to more trust.
# 0                                           Response
# 1                                              Agree
# 2                                              Agree
#
# [3 rows x 128 columns]

# %%
len(df_upload)
# Out:
# 139

# %%
len(df_header.iloc[1].to_list())
# Out:
# 128

# %% [markdown]
# ## Data preperations

# %%
# set column names
df.columns = df_header.iloc[1].to_list()
df
# Out:
#           resp_id     colle_id          start_date            end_date  \
# 0             NaN          NaN                 NaT                 NaT
# 1    1.289784e+10  404063954.0 2021-08-17 11:13:06 2021-08-17 12:04:29
# 2    1.289775e+10  404063954.0 2021-08-17 10:31:55 2021-08-17 11:16:20
# 3    1.289775e+10  404063954.0 2021-08-17 10:04:39 2021-08-17 11:13:03
# 4    1.289775e+10  404063954.0 2021-08-17 10:03:01 2021-08-17 11:12:40
# ..            ...          ...                 ...                 ...
# 134  1.288639e+10  404063954.0 2021-08-12 11:30:27 2021-08-12 11:30:35
# 135  1.288639e+10  404063954.0 2021-08-12 11:30:10 2021-08-12 11:30:23
# 136  1.288639e+10  404063954.0 2021-08-12 11:29:16 2021-08-12 11:29:24
# 137  1.288637e+10  404063954.0 2021-08-12 11:03:10 2021-08-12 11:21:44
# 138  1.288637e+10  404063954.0 2021-08-12 11:04:44 2021-08-12 11:21:36
#
#         ip_address  email  first_name  last_name  custom_data   consent  ...  \
# 0              NaN    NaN         NaN        NaN          NaN  Response  ...
# 1    160.48.234.77    NaN         NaN        NaN          NaN       Yes  ...
# 2    160.48.234.77    NaN         NaN        NaN          NaN       Yes  ...
# 3    160.48.234.77    NaN         NaN        NaN          NaN       Yes  ...
# 4    160.48.234.78    NaN         NaN        NaN          NaN       Yes  ...
# ..             ...    ...         ...        ...          ...       ...  ...
# 134  160.48.234.78    NaN         NaN        NaN          NaN       Yes  ...
# 135  160.48.234.78    NaN         NaN        NaN          NaN       Yes  ...
# 136  160.48.234.78    NaN         NaN        NaN          NaN       Yes  ...
# 137  160.48.234.77    NaN         NaN        NaN          NaN       Yes  ...
# 138  160.48.234.78    NaN         NaN        NaN          NaN       Yes  ...
#
#     sy_trust_to_adoption  sy_lack_trust_low_adoption ai_transparency_to_trust  \
# 0               Response                    Response                 Response
# 1         Very important                       Agree           Very important
# 2         Very important  Neither agree nor disagree       Somewhat important
# 3                    NaN                         NaN                      NaN
# 4    Extremely important              Strongly agree           Very important
# ..                   ...                         ...                      ...
# 134                  NaN                         NaN                      NaN
# 135  Extremely important              Strongly agree      Extremely important
# 136       Very important                       Agree           Very important
# 137   Somewhat important                       Agree           Very important
# 138  Extremely important              Strongly agree      Extremely important
#
#      ai_accountability_to_trust ai_fairness_to_trust ai_trust_to_adoption  \
# 0                      Response             Response             Response
# 1                         Agree       Very important       Very important
# 2                         Agree   Somewhat important       Very important
# 3                           NaN                  NaN                  NaN
# 4                Strongly agree       Very important       Very important
# ..                          ...                  ...                  ...
# 134                         NaN                  NaN                  NaN
# 135              Strongly agree       Very important       Very important
# 136              Strongly agree  Extremely important  Extremely important
# 137  Neither agree nor disagree   Somewhat important  Extremely important
# 138              Strongly agree  Extremely important  Extremely important
#
#     ai_lack_trust_low_adoption ai_must_be_trans_expl  \
# 0                     Response              Response
# 1                        Agree                 Agree
# 2                     Disagree                 Agree
# 3                          NaN                   NaN
# 4               Strongly agree        Strongly agree
# ..                         ...                   ...
# 134                        NaN                   NaN
# 135                      Agree                 Agree
# 136                      Agree        Strongly agree
# 137                      Agree                 Agree
# 138             Strongly agree        Strongly agree
#
#                          ai_ethical_considerations ai_fat_to_trust
# 0                              Open-Ended Response        Response
# 1                                              NaN           Agree
# 2                                              NaN           Agree
# 3                                              NaN             NaN
# 4                                              NaN  Strongly agree
# ..                                             ...             ...
# 134                                            NaN             NaN
# 135                                    Sounds good  Strongly agree
# 136                                 not to be bias  Strongly agree
# 137                                            NaN           Agree
# 138  Environmental and health impact on its users   Strongly agree
#
# [139 rows x 128 columns]

# %%
# drop unused rows
try:
    df = df.drop(0)
except:
    print('already droppen 0')
df.head()
# Out:
#         resp_id     colle_id          start_date            end_date  \
# 1  1.289784e+10  404063954.0 2021-08-17 11:13:06 2021-08-17 12:04:29
# 2  1.289775e+10  404063954.0 2021-08-17 10:31:55 2021-08-17 11:16:20
# 3  1.289775e+10  404063954.0 2021-08-17 10:04:39 2021-08-17 11:13:03
# 4  1.289775e+10  404063954.0 2021-08-17 10:03:01 2021-08-17 11:12:40
# 5  1.289773e+10  404063954.0 2021-08-17 10:05:33 2021-08-17 11:00:03
#
#       ip_address  email  first_name  last_name  custom_data consent  ...  \
# 1  160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 2  160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 3  160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 4  160.48.234.78    NaN         NaN        NaN          NaN     Yes  ...
# 5  160.48.234.78    NaN         NaN        NaN          NaN     Yes  ...
#
#   sy_trust_to_adoption  sy_lack_trust_low_adoption ai_transparency_to_trust  \
# 1       Very important                       Agree           Very important
# 2       Very important  Neither agree nor disagree       Somewhat important
# 3                  NaN                         NaN                      NaN
# 4  Extremely important              Strongly agree           Very important
# 5  Extremely important              Strongly agree       Somewhat important
#
#   ai_accountability_to_trust ai_fairness_to_trust ai_trust_to_adoption  \
# 1                      Agree       Very important       Very important
# 2                      Agree   Somewhat important       Very important
# 3                        NaN                  NaN                  NaN
# 4             Strongly agree       Very important       Very important
# 5             Strongly agree  Extremely important  Extremely important
#
#   ai_lack_trust_low_adoption ai_must_be_trans_expl ai_ethical_considerations  \
# 1                      Agree                 Agree                       NaN
# 2                   Disagree                 Agree                       NaN
# 3                        NaN                   NaN                       NaN
# 4             Strongly agree        Strongly agree                       NaN
# 5             Strongly agree                 Agree                       NaN
#
#   ai_fat_to_trust
# 1           Agree
# 2           Agree
# 3             NaN
# 4  Strongly agree
# 5           Agree
#
# [5 rows x 128 columns]

# %%
# replace agree etc with 1, 2 etc
di_agree = {'Strongly agree': 5, 'Strongly Agree':5, 'Agree': 4, 'Neither agree nor disagree': 3, 'Neither agree or disagree': 3, 'Disagree': 2, 'Strongly disagree': 1}
di_impor = {'Extremely important': 5, 'Very important': 4, 'Somewhat important': 3, 'Not so important': 2, 'Not at all important': 1}

# %%
df = df.replace({"ai_fat_to_trust": di_agree})

df.describe()
# Out:
#             resp_id     colle_id  email  first_name  last_name  custom_data  \
# count  1.380000e+02        138.0    0.0         0.0        0.0          0.0
# mean   1.288964e+10  404063954.0    NaN         NaN        NaN          NaN
# std    4.013827e+06          0.0    NaN         NaN        NaN          NaN
# min    1.288637e+10  404063954.0    NaN         NaN        NaN          NaN
# 25%    1.288657e+10  404063954.0    NaN         NaN        NaN          NaN
# 50%    1.288914e+10  404063954.0    NaN         NaN        NaN          NaN
# 75%    1.288939e+10  404063954.0    NaN         NaN        NaN          NaN
# max    1.289784e+10  404063954.0    NaN         NaN        NaN          NaN
#
#        ai_fat_to_trust
# count       135.000000
# mean          4.562963
# std           0.580882
# min           2.000000
# 25%           4.000000
# 50%           5.000000
# 75%           5.000000
# max           5.000000

# %%
# replace all agree with 1, 2...

# to do, remove open ended response questions 
# Open-Ended Response
# thislist = df_header.iloc[0].to_list()

# get columns
columnlist = list(df)

i = 0
while i < len(columnlist):
    df = df.replace({columnlist[i]: di_agree})    
    df = df.replace({columnlist[i]: di_impor})        
    
    i = i + 1

# %%
df.to_excel("data/output.xlsx")  
df
# Out:
#           resp_id     colle_id          start_date            end_date  \
# 1    1.289784e+10  404063954.0 2021-08-17 11:13:06 2021-08-17 12:04:29
# 2    1.289775e+10  404063954.0 2021-08-17 10:31:55 2021-08-17 11:16:20
# 3    1.289775e+10  404063954.0 2021-08-17 10:04:39 2021-08-17 11:13:03
# 4    1.289775e+10  404063954.0 2021-08-17 10:03:01 2021-08-17 11:12:40
# 5    1.289773e+10  404063954.0 2021-08-17 10:05:33 2021-08-17 11:00:03
# ..            ...          ...                 ...                 ...
# 134  1.288639e+10  404063954.0 2021-08-12 11:30:27 2021-08-12 11:30:35
# 135  1.288639e+10  404063954.0 2021-08-12 11:30:10 2021-08-12 11:30:23
# 136  1.288639e+10  404063954.0 2021-08-12 11:29:16 2021-08-12 11:29:24
# 137  1.288637e+10  404063954.0 2021-08-12 11:03:10 2021-08-12 11:21:44
# 138  1.288637e+10  404063954.0 2021-08-12 11:04:44 2021-08-12 11:21:36
#
#         ip_address  email  first_name  last_name  custom_data consent  ...  \
# 1    160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 2    160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 3    160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 4    160.48.234.78    NaN         NaN        NaN          NaN     Yes  ...
# 5    160.48.234.78    NaN         NaN        NaN          NaN     Yes  ...
# ..             ...    ...         ...        ...          ...     ...  ...
# 134  160.48.234.78    NaN         NaN        NaN          NaN     Yes  ...
# 135  160.48.234.78    NaN         NaN        NaN          NaN     Yes  ...
# 136  160.48.234.78    NaN         NaN        NaN          NaN     Yes  ...
# 137  160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 138  160.48.234.78    NaN         NaN        NaN          NaN     Yes  ...
#
#      sy_trust_to_adoption  sy_lack_trust_low_adoption  \
# 1                     4.0                         4.0
# 2                     4.0                         3.0
# 3                     NaN                         NaN
# 4                     5.0                         5.0
# 5                     5.0                         5.0
# ..                    ...                         ...
# 134                   NaN                         NaN
# 135                   5.0                         5.0
# 136                   4.0                         4.0
# 137                   3.0                         4.0
# 138                   5.0                         5.0
#
#      ai_transparency_to_trust  ai_accountability_to_trust  \
# 1                         4.0                         4.0
# 2                         3.0                         4.0
# 3                         NaN                         NaN
# 4                         4.0                         5.0
# 5                         3.0                         5.0
# ..                        ...                         ...
# 134                       NaN                         NaN
# 135                       5.0                         5.0
# 136                       4.0                         5.0
# 137                       4.0                         3.0
# 138                       5.0                         5.0
#
#      ai_fairness_to_trust  ai_trust_to_adoption ai_lack_trust_low_adoption  \
# 1                     4.0                   4.0                        4.0
# 2                     3.0                   4.0                        2.0
# 3                     NaN                   NaN                        NaN
# 4                     4.0                   4.0                        5.0
# 5                     5.0                   5.0                        5.0
# ..                    ...                   ...                        ...
# 134                   NaN                   NaN                        NaN
# 135                   4.0                   4.0                        4.0
# 136                   5.0                   5.0                        4.0
# 137                   3.0                   5.0                        4.0
# 138                   5.0                   5.0                        5.0
#
#     ai_must_be_trans_expl                      ai_ethical_considerations  \
# 1                     4.0                                            NaN
# 2                     4.0                                            NaN
# 3                     NaN                                            NaN
# 4                     5.0                                            NaN
# 5                     4.0                                            NaN
# ..                    ...                                            ...
# 134                   NaN                                            NaN
# 135                   4.0                                    Sounds good
# 136                   5.0                                 not to be bias
# 137                   4.0                                            NaN
# 138                   5.0  Environmental and health impact on its users
#
#     ai_fat_to_trust
# 1               4.0
# 2               4.0
# 3               NaN
# 4               5.0
# 5               4.0
# ..              ...
# 134             NaN
# 135             5.0
# 136             5.0
# 137             4.0
# 138             5.0
#
# [138 rows x 128 columns]

# %%
df.describe()
# Out:
#             resp_id     colle_id  email  first_name  last_name  custom_data  \
# count  1.380000e+02        138.0    0.0         0.0        0.0          0.0
# mean   1.288964e+10  404063954.0    NaN         NaN        NaN          NaN
# std    4.013827e+06          0.0    NaN         NaN        NaN          NaN
# min    1.288637e+10  404063954.0    NaN         NaN        NaN          NaN
# 25%    1.288657e+10  404063954.0    NaN         NaN        NaN          NaN
# 50%    1.288914e+10  404063954.0    NaN         NaN        NaN          NaN
# 75%    1.288939e+10  404063954.0    NaN         NaN        NaN          NaN
# max    1.289784e+10  404063954.0    NaN         NaN        NaN          NaN
#
#           d_tools  d_capabilities   d_culture  d_acts_on_data  ...  \
# count  138.000000      138.000000  138.000000      138.000000  ...
# mean     4.231884        4.434783    4.362319        4.333333  ...
# std      0.856830        0.724509    0.782491        0.822435  ...
# min      1.000000        1.000000    1.000000        1.000000  ...
# 25%      4.000000        4.000000    4.000000        4.000000  ...
# 50%      4.000000        5.000000    4.000000        4.500000  ...
# 75%      5.000000        5.000000    5.000000        5.000000  ...
# max      5.000000        5.000000    5.000000        5.000000  ...
#
#        sy_fairness_to_trust  sy_trust_to_adoption  sy_lack_trust_low_adoption  \
# count            136.000000            136.000000                  136.000000
# mean               4.264706              4.551471                    4.595588
# std                0.680254              0.581440                    0.744149
# min                2.000000              2.000000                    1.000000
# 25%                4.000000              4.000000                    4.000000
# 50%                4.000000              5.000000                    5.000000
# 75%                5.000000              5.000000                    5.000000
# max                5.000000              5.000000                    5.000000
#
#        ai_transparency_to_trust  ai_accountability_to_trust  \
# count                135.000000                  134.000000
# mean                   4.081481                    4.365672
# std                    0.970089                    0.710195
# min                    1.000000                    2.000000
# 25%                    4.000000                    4.000000
# 50%                    4.000000                    4.000000
# 75%                    5.000000                    5.000000
# max                    5.000000                    5.000000
#
#        ai_fairness_to_trust  ai_trust_to_adoption  ai_lack_trust_low_adoption  \
# count            135.000000            134.000000                  135.000000
# mean               4.185185              4.485075                    4.562963
# std                0.848046              0.597426                    0.593590
# min                1.000000              3.000000                    2.000000
# 25%                4.000000              4.000000                    4.000000
# 50%                4.000000              5.000000                    5.000000
# 75%                5.000000              5.000000                    5.000000
# max                5.000000              5.000000                    5.000000
#
#        ai_must_be_trans_expl  ai_fat_to_trust
# count             135.000000       135.000000
# mean                4.466667         4.562963
# std                 0.620544         0.580882
# min                 2.000000         2.000000
# 25%                 4.000000         4.000000
# 50%                 5.000000         5.000000
# 75%                 5.000000         5.000000
# max                 5.000000         5.000000
#
# [8 rows x 90 columns]

# %%
# df = df.dropna(axis='columns')

# %%
df.corr()
# Out:
#                              resp_id  colle_id  email  first_name  last_name  \
# resp_id                     1.000000       NaN    NaN         NaN        NaN
# colle_id                         NaN       NaN    NaN         NaN        NaN
# email                            NaN       NaN    NaN         NaN        NaN
# first_name                       NaN       NaN    NaN         NaN        NaN
# last_name                        NaN       NaN    NaN         NaN        NaN
# ...                              ...       ...    ...         ...        ...
# ai_fairness_to_trust       -0.073417       NaN    NaN         NaN        NaN
# ai_trust_to_adoption       -0.102927       NaN    NaN         NaN        NaN
# ai_lack_trust_low_adoption -0.031400       NaN    NaN         NaN        NaN
# ai_must_be_trans_expl      -0.051469       NaN    NaN         NaN        NaN
# ai_fat_to_trust            -0.000620       NaN    NaN         NaN        NaN
#
#                             custom_data   d_tools  d_capabilities  d_culture  \
# resp_id                             NaN -0.051081       -0.043079   0.044831
# colle_id                            NaN       NaN             NaN        NaN
# email                               NaN       NaN             NaN        NaN
# first_name                          NaN       NaN             NaN        NaN
# last_name                           NaN       NaN             NaN        NaN
# ...                                 ...       ...             ...        ...
# ai_fairness_to_trust                NaN  0.074743        0.148120   0.269700
# ai_trust_to_adoption                NaN  0.153742        0.092327   0.194956
# ai_lack_trust_low_adoption          NaN  0.184582        0.282196   0.271317
# ai_must_be_trans_expl               NaN  0.007505        0.064947   0.131465
# ai_fat_to_trust                     NaN  0.143525        0.182534   0.277253
#
#                             d_acts_on_data  ...  sy_fairness_to_trust  \
# resp_id                          -0.021872  ...             -0.009642
# colle_id                               NaN  ...                   NaN
# email                                  NaN  ...                   NaN
# first_name                             NaN  ...                   NaN
# last_name                              NaN  ...                   NaN
# ...                                    ...  ...                   ...
# ai_fairness_to_trust              0.158023  ...              0.602168
# ai_trust_to_adoption              0.214928  ...              0.287304
# ai_lack_trust_low_adoption        0.140300  ...              0.393848
# ai_must_be_trans_expl             0.094030  ...              0.330222
# ai_fat_to_trust                   0.283171  ...              0.459159
#
#                             sy_trust_to_adoption  sy_lack_trust_low_adoption  \
# resp_id                                -0.032343                    0.067846
# colle_id                                     NaN                         NaN
# email                                        NaN                         NaN
# first_name                                   NaN                         NaN
# last_name                                    NaN                         NaN
# ...                                          ...                         ...
# ai_fairness_to_trust                    0.334526                    0.214486
# ai_trust_to_adoption                    0.542360                    0.390706
# ai_lack_trust_low_adoption              0.427494                    0.437489
# ai_must_be_trans_expl                   0.289464                    0.220288
# ai_fat_to_trust                         0.414758                    0.412622
#
#                             ai_transparency_to_trust  \
# resp_id                                     0.013045
# colle_id                                         NaN
# email                                            NaN
# first_name                                       NaN
# last_name                                        NaN
# ...                                              ...
# ai_fairness_to_trust                        0.353440
# ai_trust_to_adoption                        0.163687
# ai_lack_trust_low_adoption                  0.140061
# ai_must_be_trans_expl                       0.382649
# ai_fat_to_trust                             0.249072
#
#                             ai_accountability_to_trust  ai_fairness_to_trust  \
# resp_id                                       0.038520             -0.073417
# colle_id                                           NaN                   NaN
# email                                              NaN                   NaN
# first_name                                         NaN                   NaN
# last_name                                          NaN                   NaN
# ...                                                ...                   ...
# ai_fairness_to_trust                          0.514501              1.000000
# ai_trust_to_adoption                          0.476639              0.316880
# ai_lack_trust_low_adoption                    0.490969              0.399172
# ai_must_be_trans_expl                         0.391129              0.415973
# ai_fat_to_trust                               0.447167              0.529098
#
#                             ai_trust_to_adoption  ai_lack_trust_low_adoption  \
# resp_id                                -0.102927                   -0.031400
# colle_id                                     NaN                         NaN
# email                                        NaN                         NaN
# first_name                                   NaN                         NaN
# last_name                                    NaN                         NaN
# ...                                          ...                         ...
# ai_fairness_to_trust                    0.316880                    0.399172
# ai_trust_to_adoption                    1.000000                    0.478761
# ai_lack_trust_low_adoption              0.478761                    1.000000
# ai_must_be_trans_expl                   0.322674                    0.355223
# ai_fat_to_trust                         0.381124                    0.394226
#
#                             ai_must_be_trans_expl  ai_fat_to_trust
# resp_id                                 -0.051469        -0.000620
# colle_id                                      NaN              NaN
# email                                         NaN              NaN
# first_name                                    NaN              NaN
# last_name                                     NaN              NaN
# ...                                           ...              ...
# ai_fairness_to_trust                     0.415973         0.529098
# ai_trust_to_adoption                     0.322674         0.381124
# ai_lack_trust_low_adoption               0.355223         0.394226
# ai_must_be_trans_expl                    1.000000         0.487212
# ai_fat_to_trust                          0.487212         1.000000
#
# [90 rows x 90 columns]

# %%
import seaborn as sns

# %%
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=300),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
# df.iloc[0:3, 17:34]

# %%
# df.loc[:, ['Collector ID'] ]
df.iloc[0:1, 110:] == 'Open-Ended Response'

# %%
df['Do you grant your consent as set out above?']

# %%
df.columns[0]

# %%
# df[['Custom Data 1']]


df['Custom Data 1'].unique()
