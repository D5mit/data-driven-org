# %% [markdown]
# # Data-Driven Organisations

# %% [markdown]
# ## Imports

# %%
# import pandas module 
import pandas as pd

# %% [markdown]
# ## Import Data

# %%
# import header file
df_header = pd.read_excel('data/question_headers.xlsx')  #original
df_header.iloc[0:2, 0:10]
# Out:
#   Respondent ID Collector ID  Start Date  End Date  IP Address Email Address  \
# 0           NaN          NaN         NaN       NaN         NaN           NaN
# 1       resp_id     colle_id  start_date  end_date  ip_address         email
#
#    First Name  Last Name Custom Data 1  \
# 0         NaN        NaN           NaN
# 1  first_name  last_name   custom_data
#
#   Do you grant your consent as set out above?
# 0                                    Response
# 1                                     consent

# %%
# df_header.iloc[1].to_list()

# %%
# import data file into dataframe uplaod
df_upload = pd.read_excel('data/data_113.xlsx')  
df        = pd.read_excel('data/data_113.xlsx')  #working
df_upload.head(3)
# Out:
#    Respondent ID  Collector ID          Start Date            End Date  \
# 0            NaN           NaN                 NaT                 NaT
# 1   1.289144e+10   404063954.0 2021-08-14 06:59:41 2021-08-14 07:40:27
# 2   1.288950e+10   404063954.0 2021-08-13 13:36:27 2021-08-13 15:00:02
#
#       IP Address  Email Address  First Name  Last Name  Custom Data 1  \
# 0            NaN            NaN         NaN        NaN            NaN
# 1  160.48.234.77            NaN         NaN        NaN            NaN
# 2  160.48.234.77            NaN         NaN        NaN            NaN
#
#   Do you grant your consent as set out above?  ...  \
# 0                                    Response  ...
# 1                                         Yes  ...
# 2                                         Yes  ...
#
#   From a product owner perspective, is trust an important contributor to adoption of the system?  \
# 0                                           Response
# 1                                Extremely important
# 2                                     Very important
#
#   A lack of trust will lead to a lower level of adoption of the system.  \
# 0                                           Response
# 1                                     Strongly agree
# 2                                              Agree
#
#   From a product owner perspective, do you think the transparency of an AI application's logic is important/beneficial for trustworthiness? Transparency is, for example, the explainability of the machine learning decision/predictive process.  \
# 0                                           Response
# 1                                     Very important
# 2                                     Very important
#
#   From a product owner perspective, do you think assigning accountability of a AI application's actions is important/beneficial for trustworthiness? Accountability would be, for example, who is accountable when an autonomous vehicle crashes.  \
# 0                                           Response
# 1                                              Agree
# 2                                     Strongly agree
#
#   From a product owner perspective, do you think the fairness of the AI application's actions is important for trustworthiness. For example, demographic biases in the automation of credit vetting.  \
# 0                                           Response
# 1                                 Somewhat important
# 2                                     Very important
#
#   From a product owner perspective, is trustworthiness an important contributor to the adoption of the system?  \
# 0                                           Response
# 1                                     Very important
# 2                                     Very important
#
#   A lack of trust in the process around an AI system will lead to a lower level of adoption of the AI application.  \
# 0                                           Response
# 1                                              Agree
# 2                                     Strongly agree
#
#   Organisations need to ensure that the AI applications that they develop are transparent (allow explainability) in their actions.  \
# 0                                           Response
# 1                                     Strongly agree
# 2                                              Agree
#
#   If any, what ethical considerations other than fairness, transparency and accountability should organisations have when they develop AI applications?  \
# 0                                Open-Ended Response
# 1                                            neutral
# 2  AI is not neutral, it makes "decisions" based ...
#
#   Ensuring that AI applications are fair, accountable and transparent, will lead to more trust.
# 0                                           Response
# 1                                     Strongly agree
# 2                                              Agree
#
# [3 rows x 128 columns]

# %%
len(df_upload)
# Out:
# 114

# %%
len(df_header.iloc[1].to_list())
# Out:
# 128

# %% [markdown]
# ## Data preperations

# %%
# set column names
df.columns = df_header.iloc[1].to_list()
df
# Out:
#           resp_id     colle_id          start_date            end_date  \
# 0             NaN          NaN                 NaT                 NaT
# 1    1.289144e+10  404063954.0 2021-08-14 06:59:41 2021-08-14 07:40:27
# 2    1.288950e+10  404063954.0 2021-08-13 13:36:27 2021-08-13 15:00:02
# 3    1.288948e+10  404063954.0 2021-08-13 13:36:10 2021-08-13 14:50:10
# 4    1.288945e+10  404063954.0 2021-08-13 13:39:14 2021-08-13 14:37:46
# ..            ...          ...                 ...                 ...
# 109  1.288639e+10  404063954.0 2021-08-12 11:30:27 2021-08-12 11:30:35
# 110  1.288639e+10  404063954.0 2021-08-12 11:30:10 2021-08-12 11:30:23
# 111  1.288639e+10  404063954.0 2021-08-12 11:29:16 2021-08-12 11:29:24
# 112  1.288637e+10  404063954.0 2021-08-12 11:03:10 2021-08-12 11:21:44
# 113  1.288637e+10  404063954.0 2021-08-12 11:04:44 2021-08-12 11:21:36
#
#         ip_address  email  first_name  last_name  custom_data   consent  ...  \
# 0              NaN    NaN         NaN        NaN          NaN  Response  ...
# 1    160.48.234.77    NaN         NaN        NaN          NaN       Yes  ...
# 2    160.48.234.77    NaN         NaN        NaN          NaN       Yes  ...
# 3    160.48.234.77    NaN         NaN        NaN          NaN       Yes  ...
# 4    160.48.234.77    NaN         NaN        NaN          NaN       Yes  ...
# ..             ...    ...         ...        ...          ...       ...  ...
# 109  160.48.234.78    NaN         NaN        NaN          NaN       Yes  ...
# 110  160.48.234.78    NaN         NaN        NaN          NaN       Yes  ...
# 111  160.48.234.78    NaN         NaN        NaN          NaN       Yes  ...
# 112  160.48.234.77    NaN         NaN        NaN          NaN       Yes  ...
# 113  160.48.234.78    NaN         NaN        NaN          NaN       Yes  ...
#
#     sy_trust_to_adoption sy_lack_trust_low_adoption ai_transparency_to_trust  \
# 0               Response                   Response                 Response
# 1    Extremely important             Strongly agree           Very important
# 2         Very important                      Agree           Very important
# 3         Very important             Strongly agree           Very important
# 4         Very important             Strongly agree           Very important
# ..                   ...                        ...                      ...
# 109                  NaN                        NaN                      NaN
# 110  Extremely important             Strongly agree      Extremely important
# 111       Very important                      Agree           Very important
# 112   Somewhat important                      Agree           Very important
# 113  Extremely important             Strongly agree      Extremely important
#
#      ai_accountability_to_trust ai_fairness_to_trust ai_trust_to_adoption  \
# 0                      Response             Response             Response
# 1                         Agree   Somewhat important       Very important
# 2                Strongly agree       Very important       Very important
# 3                Strongly agree  Extremely important       Very important
# 4                         Agree       Very important       Very important
# ..                          ...                  ...                  ...
# 109                         NaN                  NaN                  NaN
# 110              Strongly agree       Very important       Very important
# 111              Strongly agree  Extremely important  Extremely important
# 112  Neither agree nor disagree   Somewhat important  Extremely important
# 113              Strongly agree  Extremely important  Extremely important
#
#     ai_lack_trust_low_adoption ai_must_be_trans_expl  \
# 0                     Response              Response
# 1                        Agree        Strongly agree
# 2               Strongly agree                 Agree
# 3               Strongly agree        Strongly agree
# 4               Strongly agree        Strongly agree
# ..                         ...                   ...
# 109                        NaN                   NaN
# 110                      Agree                 Agree
# 111                      Agree        Strongly agree
# 112                      Agree                 Agree
# 113             Strongly agree        Strongly agree
#
#                              ai_ethical_considerations ai_fat_to_trust
# 0                                  Open-Ended Response        Response
# 1                                              neutral  Strongly agree
# 2    AI is not neutral, it makes "decisions" based ...           Agree
# 3                   unbiased, critical thinking skills  Strongly agree
# 4    There should be a humane angle in this if at a...           Agree
# ..                                                 ...             ...
# 109                                                NaN             NaN
# 110                                        Sounds good  Strongly agree
# 111                                     not to be bias  Strongly agree
# 112                                                NaN           Agree
# 113      Environmental and health impact on its users   Strongly agree
#
# [114 rows x 128 columns]

# %%
# drop unused rows
try:
    df = df.drop(0)
except:
    print('already droppen 0')
df.head()
# Out:
#         resp_id     colle_id          start_date            end_date  \
# 1  1.289144e+10  404063954.0 2021-08-14 06:59:41 2021-08-14 07:40:27
# 2  1.288950e+10  404063954.0 2021-08-13 13:36:27 2021-08-13 15:00:02
# 3  1.288948e+10  404063954.0 2021-08-13 13:36:10 2021-08-13 14:50:10
# 4  1.288945e+10  404063954.0 2021-08-13 13:39:14 2021-08-13 14:37:46
# 5  1.288943e+10  404063954.0 2021-08-13 13:41:44 2021-08-13 14:25:44
#
#       ip_address  email  first_name  last_name  custom_data consent  ...  \
# 1  160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 2  160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 3  160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 4  160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 5  160.48.234.78    NaN         NaN        NaN          NaN     Yes  ...
#
#   sy_trust_to_adoption sy_lack_trust_low_adoption ai_transparency_to_trust  \
# 1  Extremely important             Strongly agree           Very important
# 2       Very important                      Agree           Very important
# 3       Very important             Strongly agree           Very important
# 4       Very important             Strongly agree           Very important
# 5       Very important             Strongly agree       Somewhat important
#
#   ai_accountability_to_trust ai_fairness_to_trust ai_trust_to_adoption  \
# 1                      Agree   Somewhat important       Very important
# 2             Strongly agree       Very important       Very important
# 3             Strongly agree  Extremely important       Very important
# 4                      Agree       Very important       Very important
# 5                      Agree       Very important       Very important
#
#   ai_lack_trust_low_adoption ai_must_be_trans_expl  \
# 1                      Agree        Strongly agree
# 2             Strongly agree                 Agree
# 3             Strongly agree        Strongly agree
# 4             Strongly agree        Strongly agree
# 5                      Agree                 Agree
#
#                            ai_ethical_considerations ai_fat_to_trust
# 1                                            neutral  Strongly agree
# 2  AI is not neutral, it makes "decisions" based ...           Agree
# 3                 unbiased, critical thinking skills  Strongly agree
# 4  There should be a humane angle in this if at a...           Agree
# 5                                                NaN           Agree
#
# [5 rows x 128 columns]

# %%
# replace agree etc with 1, 2 etc
di_agree = {'Strongly agree': 5, 'Strongly Agree':5, 'Agree': 4, 'Neither agree nor disagree': 3, 'Neither agree or disagree': 3, 'Disagree': 2, 'Strongly disagree': 1}
di_impor = {'Extremely important': 5, 'Very important': 4, 'Somewhat important': 3, 'Not so important': 2, 'Not at all important': 1}

# %%
df = df.replace({"ai_fat_to_trust": di_agree})

df.describe()
# Out:
#             resp_id     colle_id  email  first_name  last_name  custom_data  \
# count  1.130000e+02        113.0    0.0         0.0        0.0          0.0
# mean   1.288786e+10  404063954.0    NaN         NaN        NaN          NaN
# std    1.406110e+06          0.0    NaN         NaN        NaN          NaN
# min    1.288637e+10  404063954.0    NaN         NaN        NaN          NaN
# 25%    1.288642e+10  404063954.0    NaN         NaN        NaN          NaN
# 50%    1.288678e+10  404063954.0    NaN         NaN        NaN          NaN
# 75%    1.288917e+10  404063954.0    NaN         NaN        NaN          NaN
# max    1.289144e+10  404063954.0    NaN         NaN        NaN          NaN
#
#        ai_fat_to_trust
# count       111.000000
# mean          4.567568
# std           0.597291
# min           2.000000
# 25%           4.000000
# 50%           5.000000
# 75%           5.000000
# max           5.000000

# %%
# replace all agree with 1, 2...

# to do, remove open ended response questions 
# Open-Ended Response
# thislist = df_header.iloc[0].to_list()

# get columns
columnlist = list(df)

i = 0
while i < len(columnlist):
    df = df.replace({columnlist[i]: di_agree})    
    df = df.replace({columnlist[i]: di_impor})        
    
    i = i + 1

# %%
df.to_excel("data/output.xlsx")  
df
# Out:
#           resp_id     colle_id          start_date            end_date  \
# 1    1.289144e+10  404063954.0 2021-08-14 06:59:41 2021-08-14 07:40:27
# 2    1.288950e+10  404063954.0 2021-08-13 13:36:27 2021-08-13 15:00:02
# 3    1.288948e+10  404063954.0 2021-08-13 13:36:10 2021-08-13 14:50:10
# 4    1.288945e+10  404063954.0 2021-08-13 13:39:14 2021-08-13 14:37:46
# 5    1.288943e+10  404063954.0 2021-08-13 13:41:44 2021-08-13 14:25:44
# ..            ...          ...                 ...                 ...
# 109  1.288639e+10  404063954.0 2021-08-12 11:30:27 2021-08-12 11:30:35
# 110  1.288639e+10  404063954.0 2021-08-12 11:30:10 2021-08-12 11:30:23
# 111  1.288639e+10  404063954.0 2021-08-12 11:29:16 2021-08-12 11:29:24
# 112  1.288637e+10  404063954.0 2021-08-12 11:03:10 2021-08-12 11:21:44
# 113  1.288637e+10  404063954.0 2021-08-12 11:04:44 2021-08-12 11:21:36
#
#         ip_address  email  first_name  last_name  custom_data consent  ...  \
# 1    160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 2    160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 3    160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 4    160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 5    160.48.234.78    NaN         NaN        NaN          NaN     Yes  ...
# ..             ...    ...         ...        ...          ...     ...  ...
# 109  160.48.234.78    NaN         NaN        NaN          NaN     Yes  ...
# 110  160.48.234.78    NaN         NaN        NaN          NaN     Yes  ...
# 111  160.48.234.78    NaN         NaN        NaN          NaN     Yes  ...
# 112  160.48.234.77    NaN         NaN        NaN          NaN     Yes  ...
# 113  160.48.234.78    NaN         NaN        NaN          NaN     Yes  ...
#
#      sy_trust_to_adoption  sy_lack_trust_low_adoption  \
# 1                     5.0                         5.0
# 2                     4.0                         4.0
# 3                     4.0                         5.0
# 4                     4.0                         5.0
# 5                     4.0                         5.0
# ..                    ...                         ...
# 109                   NaN                         NaN
# 110                   5.0                         5.0
# 111                   4.0                         4.0
# 112                   3.0                         4.0
# 113                   5.0                         5.0
#
#      ai_transparency_to_trust  ai_accountability_to_trust  \
# 1                         4.0                         4.0
# 2                         4.0                         5.0
# 3                         4.0                         5.0
# 4                         4.0                         4.0
# 5                         3.0                         4.0
# ..                        ...                         ...
# 109                       NaN                         NaN
# 110                       5.0                         5.0
# 111                       4.0                         5.0
# 112                       4.0                         3.0
# 113                       5.0                         5.0
#
#      ai_fairness_to_trust  ai_trust_to_adoption ai_lack_trust_low_adoption  \
# 1                     3.0                   4.0                        4.0
# 2                     4.0                   4.0                        5.0
# 3                     5.0                   4.0                        5.0
# 4                     4.0                   4.0                        5.0
# 5                     4.0                   4.0                        4.0
# ..                    ...                   ...                        ...
# 109                   NaN                   NaN                        NaN
# 110                   4.0                   4.0                        4.0
# 111                   5.0                   5.0                        4.0
# 112                   3.0                   5.0                        4.0
# 113                   5.0                   5.0                        5.0
#
#     ai_must_be_trans_expl                          ai_ethical_considerations  \
# 1                     5.0                                            neutral
# 2                     4.0  AI is not neutral, it makes "decisions" based ...
# 3                     5.0                 unbiased, critical thinking skills
# 4                     5.0  There should be a humane angle in this if at a...
# 5                     4.0                                                NaN
# ..                    ...                                                ...
# 109                   NaN                                                NaN
# 110                   4.0                                        Sounds good
# 111                   5.0                                     not to be bias
# 112                   4.0                                                NaN
# 113                   5.0      Environmental and health impact on its users
#
#     ai_fat_to_trust
# 1               5.0
# 2               4.0
# 3               5.0
# 4               4.0
# 5               4.0
# ..              ...
# 109             NaN
# 110             5.0
# 111             5.0
# 112             4.0
# 113             5.0
#
# [113 rows x 128 columns]

# %%
df.describe()
# Out:
#             resp_id     colle_id  email  first_name  last_name  custom_data  \
# count  1.130000e+02        113.0    0.0         0.0        0.0          0.0
# mean   1.288786e+10  404063954.0    NaN         NaN        NaN          NaN
# std    1.406110e+06          0.0    NaN         NaN        NaN          NaN
# min    1.288637e+10  404063954.0    NaN         NaN        NaN          NaN
# 25%    1.288642e+10  404063954.0    NaN         NaN        NaN          NaN
# 50%    1.288678e+10  404063954.0    NaN         NaN        NaN          NaN
# 75%    1.288917e+10  404063954.0    NaN         NaN        NaN          NaN
# max    1.289144e+10  404063954.0    NaN         NaN        NaN          NaN
#
#           d_tools  d_capabilities   d_culture  d_acts_on_data  ...  \
# count  113.000000      113.000000  113.000000      113.000000  ...
# mean     4.238938        4.442478    4.336283        4.336283  ...
# std      0.918795        0.755197    0.830347        0.851581  ...
# min      1.000000        1.000000    1.000000        1.000000  ...
# 25%      4.000000        4.000000    4.000000        4.000000  ...
# 50%      4.000000        5.000000    4.000000        5.000000  ...
# 75%      5.000000        5.000000    5.000000        5.000000  ...
# max      5.000000        5.000000    5.000000        5.000000  ...
#
#        sy_fairness_to_trust  sy_trust_to_adoption  sy_lack_trust_low_adoption  \
# count            112.000000            112.000000                  112.000000
# mean               4.267857              4.562500                    4.589286
# std                0.697255              0.597008                    0.777540
# min                2.000000              2.000000                    1.000000
# 25%                4.000000              4.000000                    4.000000
# 50%                4.000000              5.000000                    5.000000
# 75%                5.000000              5.000000                    5.000000
# max                5.000000              5.000000                    5.000000
#
#        ai_transparency_to_trust  ai_accountability_to_trust  \
# count                111.000000                  110.000000
# mean                   4.063063                    4.354545
# std                    1.011563                    0.736796
# min                    1.000000                    2.000000
# 25%                    4.000000                    4.000000
# 50%                    4.000000                    4.000000
# 75%                    5.000000                    5.000000
# max                    5.000000                    5.000000
#
#        ai_fairness_to_trust  ai_trust_to_adoption  ai_lack_trust_low_adoption  \
# count            111.000000            110.000000                  111.000000
# mean               4.207207              4.509091                    4.585586
# std                0.875080              0.601915                    0.563568
# min                1.000000              3.000000                    3.000000
# 25%                4.000000              4.000000                    4.000000
# 50%                4.000000              5.000000                    5.000000
# 75%                5.000000              5.000000                    5.000000
# max                5.000000              5.000000                    5.000000
#
#        ai_must_be_trans_expl  ai_fat_to_trust
# count             111.000000       111.000000
# mean                4.486486         4.567568
# std                 0.644767         0.597291
# min                 2.000000         2.000000
# 25%                 4.000000         4.000000
# 50%                 5.000000         5.000000
# 75%                 5.000000         5.000000
# max                 5.000000         5.000000
#
# [8 rows x 90 columns]

# %%
# df = df.dropna(axis='columns')

# %%
df.corr()
# Out:
#                            resp_id  colle_id   d_tools  d_capabilities  \
# resp_id                   1.000000       NaN -0.113170       -0.072089
# colle_id                       NaN       NaN       NaN             NaN
# d_tools                  -0.113170       NaN  1.000000        0.656939
# d_capabilities           -0.072089       NaN  0.656939        1.000000
# d_culture                -0.074119       NaN  0.525711        0.671853
# ...                            ...       ...       ...             ...
# platf_sh_trialability    -0.172688       NaN  0.222855        0.266415
# platf_sh_observability   -0.143543       NaN  0.221303        0.318157
# platf_sh_less_complexity -0.098473       NaN  0.193628        0.232874
# platf_sh_accountable     -0.068635       NaN  0.256385        0.252090
# platf_sh_fair            -0.103999       NaN  0.240363        0.229879
#
#                           d_culture  d_acts_on_data  d_fin_benefits  \
# resp_id                   -0.074119       -0.049657       -0.071348
# colle_id                        NaN             NaN             NaN
# d_tools                    0.525711        0.489780        0.475192
# d_capabilities             0.671853        0.544033        0.602396
# d_culture                  1.000000        0.684646        0.708077
# ...                             ...             ...             ...
# platf_sh_trialability      0.268172        0.304453        0.312150
# platf_sh_observability     0.314647        0.321700        0.362979
# platf_sh_less_complexity   0.188953        0.219528        0.271126
# platf_sh_accountable       0.230932        0.212138        0.345905
# platf_sh_fair              0.265377        0.232804        0.366463
#
#                           d_non_fin_benefits  m_maturity_rating   mo_size  \
# resp_id                             0.000637           0.000439 -0.092985
# colle_id                                 NaN                NaN       NaN
# d_tools                             0.399016           0.179063  0.260380
# d_capabilities                      0.455233           0.232673  0.130000
# d_culture                           0.599163           0.189467  0.081270
# ...                                      ...                ...       ...
# platf_sh_trialability               0.134669           0.032041  0.039186
# platf_sh_observability              0.267354           0.054114  0.017935
# platf_sh_less_complexity            0.106184           0.219011  0.154387
# platf_sh_accountable                0.305691           0.080848  0.087107
# platf_sh_fair                       0.327621           0.101820  0.136703
#
#                           ...  tools_sh_less_complexity  tools_sh_accountable  \
# resp_id                   ...                 -0.077114              0.030061
# colle_id                  ...                       NaN                   NaN
# d_tools                   ...                  0.227329              0.220734
# d_capabilities            ...                  0.211732              0.243848
# d_culture                 ...                  0.227158              0.254272
# ...                       ...                       ...                   ...
# platf_sh_trialability     ...                  0.359167              0.573007
# platf_sh_observability    ...                  0.398594              0.630102
# platf_sh_less_complexity  ...                  0.604128              0.468997
# platf_sh_accountable      ...                  0.401401              0.756678
# platf_sh_fair             ...                  0.366594              0.709670
#
#                           tools_sh_fair  platf_sh_relative_advantage  \
# resp_id                        0.062310                    -0.146656
# colle_id                            NaN                          NaN
# d_tools                        0.142217                     0.290340
# d_capabilities                 0.247523                     0.341787
# d_culture                      0.230672                     0.347236
# ...                                 ...                          ...
# platf_sh_trialability          0.460611                     0.632876
# platf_sh_observability         0.587583                     0.663320
# platf_sh_less_complexity       0.437724                     0.523811
# platf_sh_accountable           0.759269                     0.587263
# platf_sh_fair                  0.822622                     0.625131
#
#                           platf_sh_compatibility  platf_sh_trialability  \
# resp_id                                -0.286105              -0.172688
# colle_id                                     NaN                    NaN
# d_tools                                 0.240671               0.222855
# d_capabilities                          0.221284               0.266415
# d_culture                               0.228850               0.268172
# ...                                          ...                    ...
# platf_sh_trialability                   0.652093               1.000000
# platf_sh_observability                  0.682321               0.801542
# platf_sh_less_complexity                0.577741               0.544179
# platf_sh_accountable                    0.559773               0.658086
# platf_sh_fair                           0.567466               0.621542
#
#                           platf_sh_observability  platf_sh_less_complexity  \
# resp_id                                -0.143543                 -0.098473
# colle_id                                     NaN                       NaN
# d_tools                                 0.221303                  0.193628
# d_capabilities                          0.318157                  0.232874
# d_culture                               0.314647                  0.188953
# ...                                          ...                       ...
# platf_sh_trialability                   0.801542                  0.544179
# platf_sh_observability                  1.000000                  0.594644
# platf_sh_less_complexity                0.594644                  1.000000
# platf_sh_accountable                    0.734649                  0.583091
# platf_sh_fair                           0.696557                  0.568036
#
#                           platf_sh_accountable  platf_sh_fair
# resp_id                              -0.068635      -0.103999
# colle_id                                   NaN            NaN
# d_tools                               0.256385       0.240363
# d_capabilities                        0.252090       0.229879
# d_culture                             0.230932       0.265377
# ...                                        ...            ...
# platf_sh_trialability                 0.658086       0.621542
# platf_sh_observability                0.734649       0.696557
# platf_sh_less_complexity              0.583091       0.568036
# platf_sh_accountable                  1.000000       0.910758
# platf_sh_fair                         0.910758       1.000000
#
# [74 rows x 74 columns]

# %%
import seaborn as sns

# %%
corr = df.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=300),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
# df.iloc[0:3, 17:34]

# %%
# df.loc[:, ['Collector ID'] ]
df.iloc[0:1, 110:] == 'Open-Ended Response'

# %%
df['Do you grant your consent as set out above?']

# %%
df.columns[0]

# %%
# df[['Custom Data 1']]


df['Custom Data 1'].unique()
