# %%
# Importing modules
import pandas as pd
import os
# Import the wordcloud library
from wordcloud import WordCloud
import matplotlib.pyplot as plt

import nltk
nltk.download('wordnet')
from nltk.stem.wordnet import WordNetLemmatizer

import gensim
from gensim.utils import simple_preprocess
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import gensim.corpora as corpora
from pprint import pprint

import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
import pickle 

import seaborn
# Out:
# [nltk_data] Downloading package wordnet to /home/d5mit/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/d5mit/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        # deacc=True removes punctuations
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

# %%
df_text = pd.read_excel(open('data/diffusion_innovation_open_ended.xls','rb'), sheet_name='diffusion_innovation_open_ended')# Print head
df_text.head()
# Out:
#                                            knowledge  \
# 0                                     Share insights
# 1  Have a space that is central in which all pers...
# 2                     Share examples of how it works
# 3       Continuous exposure, upskilling and training
# 4  I would spread the responsibility and put in a...
#
#                                           persuasion  \
# 0            Lead by example, do not lead on opinion
# 1  Describe the benefits and how it can lead to m...
# 2                     Share examples of how it works
# 3  Introduction presentations and demos of data d...
# 4  Selling the value and efficiency that it bring...
#
#                                             decision  \
# 0                                      I do not know
# 1  Clear advantages - For an organisation and its...
# 2                Will the benefits outweigh the cons
# 3                       Cross platform compatibility
# 4  Whether you want to survive as an organisation...
#
#               implementation  \
# 0                yes I would
# 1                        Yes
# 2  don't understand question
# 3                        yes
# 4                        Yes
#
#                                         confirmation  \
# 0                                  Facts and figures
# 1  Before implementing the transformation a set o...
# 2  monitor things like sales, productivity, worke...
# 3  Streamlining/enhancement of the current proced...
# 4  Increase in usage of data / analytics tool. Ex...
#
#                                             momentum
# 0                              Focus on the win-wins
# 1  Consistency & small changes - transformation s...
# 2                     Share examples of how it works
# 3  Acknowledge the barries and listen to the push...
# 4  Resolving the barriers as soon as possible and...

# %%
list_columns = df_text.columns.to_list()
list_columns
for i_column in list_columns:
    df_text[i_column]      = df_text[i_column].str.replace('[^a-zA-Z0-9]', ' ').values.astype(str)
# Out:
# /tmp/ipykernel_10424/4273977713.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_text[i_column]      = df_text[i_column].str.replace('[^a-zA-Z0-9]', ' ').values.astype(str)

# %%
i_stage = 'knowledge'
num_topics = 7

# get data
data = df_text[i_stage].values.tolist()

# convert data to words
data_words = list(sent_to_words(data))

data_words

# # # Reduce words to their root form
# lemmed = [WordNetLemmatizer().lemmatize(w) for w in data]
# print(lemmed)

print(data_words[0])

idocs = []
for doc in data_words:
    lemmed = [WordNetLemmatizer().lemmatize(w) for w in doc]
    idocs.append(lemmed)
    
print(idocs)    
# # # Reduce words to their root form
# lemmed = [WordNetLemmatizer().lemmatize(w) for w in data_words[0]]
# print(lemmed)
# Out:
# ['share', 'insights']
# [['share', 'insight'], ['have', 'space', 'that', 'is', 'central', 'in', 'which', 'all', 'person', 'can', 'access', 'where', 'useful', 'topic', 'and', 'training', 'can', 'be', 'accessed'], ['share', 'example', 'of', 'how', 'it', 'work'], ['continuous', 'exposure', 'upskilling', 'and', 'training'], ['would', 'spread', 'the', 'responsibility', 'and', 'put', 'in', 'great', 'amount', 'of', 'effort', 'in', 'upskilling', 'and', 'obtaining', 'buy', 'in', 'of', 'non', 'it', 'department'], ['by', 'sending', 'people', 'to', 'training', 'and', 'helping', 'them', 'obtain', 'new', 'skill', 'and', 'making', 'sure', 'they', 'work', 'with', 'the', 'tool', 'a', 'frequent'], ['training', 'individual', 'and', 'having', 'in', 'house', 'opportunity', 'for', 'them', 'to', 'be', 'involved'], ['drive', 'business', 'process', 'ownership', 'in', 'collective', 'fashion', 'business', 'and', 'it'], ['implement', 'such', 'system', 'a', 'part', 'of', 'daily', 'use', 'to', 'make', 'user', 'more', 'familiar', 'with', 'thinking', 'outside', 'the', 'box', 'in', 'hr', 'system', 'allow', 'analysis', 'of', 'leave', 'hour', 'worked', 'or', 'something', 'like', 'that', 'compare', 'my', 'leave', 'with', 'the', 'average', 'etc'], ['by', 'improving', 'data', 'quality', 'access', 'contro'], ['more', 'regular', 'communication', 'of', 'success', 'story'], ['get', 'people', 'skilled'], ['training', 'inculturation'], ['would', 'get', 'volunteer', 'within', 'the', 'organization', 'and', 'rd', 'party', 'vendor', 'to', 'give', 'there', 'best', 'idea', 'and', 'send', 'short', 'email', 'every', 'friday', 'with', 'the', 'one', 'best', 'idea', 'from', 'all', 'the', 'idea', 'we', 'receive', 'from', 'the', 'volunteer'], ['would', 'work', 'on', 'creating', 'culture', 'that', 'appreciates', 'the', 'benefit', 'of', 'data', 'by', 'educating', 'and', 'running', 'regular', 'data', 'training', 'session'], ['training'], ['frequent', 'technology', 'session', 'between', 'multiple', 'stream'], ['training'], ['training', 'and', 'applying', 'the', 'knowledge', 'so', 'practice', 'practice'], ['through', 'training'], ['training', 'session', 'assistance'], ['sending', 'employee', 'to', 'training', 'regularly', 'sometimes', 'employee', 'have', 'the', 'skill', 'but', 'have', 'not', 'used', 'it', 'in', 'long', 'time'], ['allow', 'employee', 'to', 'invest', 'time', 'in', 'building', 'pilot', 'training', 'and', 'conference'], ['provide', 'more', 'access', 'to', 'tool'], ['various', 'training', 'hand', 'on', 'experience'], ['training', 'and', 'awareness', 'a', 'part', 'of', 'onboarding', 'procedure'], ['online', 'and', 'onsite', 'training'], ['training', 'and', 'pilot', 'project', 'to', 'see', 'benefit', 'and', 'clear', 'example', 'of', 'how', 'to', 'implement'], ['get', 'the', 'business', 'involved', 'with', 'roadshows', 'to', 'show', 'what', 'is', 'available'], ['knowledge', 'sharing', 'on', 'seminar'], ['training', 'and', 'forum'], ['platform', 'forum', 'to', 'start', 'with', 'nobody', 'is', 'talking', 'about', 'these', 'thing', 'look', 'at', 'the', 'covid', 'situation', 'changing', 'how', 'we', 'work', 'there', 'is', 'no', 'more', 'corridor', 'chat', 'were', 'this', 'type', 'of', 'knowledge', 'is', 'share', 'space', 'like', 'confluence', 'm', 'team', 'are', 'great', 'tool', 'for', 'this'], ['active', 'training'], ['making', 'data', 'analytics', 'tool', 'available', 'to', 'all', 'department', 'and', 'offering', 'training'], ['more', 'exposure', 'to', 'new', 'technology', 'that', 'drive', 'data', 'management', 'within', 'the', 'organization'], ['training', 'training', 'and', 'more', 'training'], ['visibility', 'on', 'comprehensive', 'level', 'and', 'roadshows'], ['proved', 'to', 'be', 'useful', 'to', 'user', 'base'], ['empower', 'all', 'employee', 'hold', 'people', 'responsible'], [], ['encourage', 'people', 'to', 'attend', 'more', 'analytical', 'training'], ['read', 'up', 'on', 'it', 'and', 'implement', 'where', 'can'], ['need', 'to', 'build', 'program', 'karen'], ['constant', 'training', 'and', 'aware ...

# %%
data_words
# Out:
# [['share', 'insights'],
#  ['have',
#   'space',
#   'that',
#   'is',
#   'central',
#   'in',
#   'which',
#   'all',
#   'person',
#   'can',
#   'access',
#   'where',
#   'useful',
#   'topics',
#   'and',
#   'trainings',
#   'can',
#   'be',
#   'accessed'],
#  ['share', 'examples', 'of', 'how', 'it', 'works'],
#  ['continuous', 'exposure', 'upskilling', 'and', 'training'],
#  ['would',
#   'spread',
#   'the',
#   'responsibility',
#   'and',
#   'put',
#   'in',
#   'great',
#   'amount',
#   'of',
#   'effort',
#   'in',
#   'upskilling',
#   'and',
#   'obtaining',
#   'buy',
#   'in',
#   'of',
#   'non',
#   'it',
#   'departments'],
#  ['by',
#   'sending',
#   'people',
#   'to',
#   'training',
#   'and',
#   'helping',
#   'them',
#   'obtain',
#   'new',
#   'skills',
#   'and',
#   'making',
#   'sure',
#   'they',
#   'work',
#   'with',
#   'the',
#   'tools',
#   'as',
#   'frequent'],
#  ['training',
#   'individuals',
#   'and',
#   'having',
#   'in',
#   'house',
#   'opportunities',
#   'for',
#   'them',
#   'to',
#   'be',
#   'involved'],
#  ['drive',
#   'business',
#   'process',
#   'ownership',
#   'in',
#   'collective',
#   'fashion',
#   'business',
#   'and',
#   'it'],
#  ['implement',
#   'such',
#   'systems',
#   'as',
#   'part',
#   'of',
#   'daily',
#   'use',
#   'to',
#   'make',
#   'users',
#   'more',
#   'familiar',
#   'with',
#   'thinking',
#   'outside',
#   'the',
#   'box',
#   'in',
#   'hr',
#   'systems',
#   'allow',
#   'analysis',
#   'of',
#   'leave',
#   'hours',
#   'worked',
#   'or',
#   'something',
#   'like',
#   'that',
#   'compare',
#   'my',
#   'leave',
#   'with',
#   'the',
#   'average',
#   'etc'],
#  ['by', 'improving', 'data', 'quality', 'access', 'contro'],
#  ['more', 'regular', 'communication', 'of', 'success', 'stories'],
#  ['get', 'people', 'skilled'],
#  ['training', 'inculturation'],
#  ['would',
#   'get',
#   'volunteers',
#   'within',
#   'the',
#   'organization',
#   'and',
#   'rd',
#   'party',
#   'vendors',
#   'to',
#   'give',
#   'there',
#   'best',
#   'ideas',
#   'and',
#   'send',
#   'short',
#   'email',
#   'every',
#   'friday',
#   'with',
#   'the',
#   'one',
#   'best',
#   'idea',
#   'from',
#   'all',
#   'the',
#   'ideas',
#   'we',
#   'receive',
#   'from',
#   'the',
#   'volunteers'],
#  ['would',
#   'work',
#   'on',
#   'creating',
#   'culture',
#   'that',
#   'appreciates',
#   'the',
#   'benefits',
#   'of',
#   'data',
#   'by',
#   'educating',
#   'and',
#   'running',
#   'regular',
#   'data',
#   'training',
#   'sessions'],
#  ['training'],
#  ['frequent', 'technology', 'sessions', 'between', 'multiple', 'streams'],
#  ['training'],
#  ['training',
#   'and',
#   'applying',
#   'the',
#   'knowledge',
#   'so',
#   'practice',
#   'practice'],
#  ['through', 'training'],
#  ['training', 'sessions', 'assistance'],
#  ['sending',
#   'employees',
#   'to',
#   'training',
#   'regularly',
#   'sometimes',
#   'employees',
#   'have',
#   'the',
#   'skill',
#   'but',
#   'have',
#   'not',
#   'used',
#   'it',
#   'in',
#   'long',
#   'time'],
#  ['allow',
#   'employees',
#   'to',
#   'invest',
#   'time',
#   'in',
#   'building',
#   'pilots',
#   'training',
#   'and',
#   'conferences'],
#  ['provide', 'more', 'access', 'to', 'tools'],
#  ['various', 'training', 'hands', 'on', 'experience'],
#  ['training',
#   'and',
#   'awareness',
#   'as',
#   'part',
#   'of',
#   'onboarding',
#   'procedures'],
#  ['online', 'and', 'onsite', 'training'],
#  ['training',
#   'and',
#   'pilot',
#   'projects',
#   'to',
#   'see',
#   'benefits',
#   'and',
#   'clear',
#   'examples',
#   'of',
#   'how',
#   'to',
#   'implement'],
#  ['get',
#   'the',
#   'business',
#   'involved',
#   'with',
#   'roadshows',
#   'to',
#   'show',
#   'what',
#   'is',
#   'available'],
#  ['knowledge', 'sharing', 'on', 'seminars'],
#  ['training', 'and', 'forums'],
#  ['platforms',
#   'forums',
#   'to',
#   'start',
#   'with',
#   'nobody',
#   'is',
#   'talking',
#   'about',
#   'these',
#   'thing',
#   'look',
#   'at',
#   'the',
#   'covid',
#   'situation',
#   'changing',
#   'how',
#   'we',
#   'work',
#   'there',
#   'is',
#   'no',
#   'more',
#   'corridor',
#   'chat',
#   'were',
#   'this',
#   'type',
#   'of',
#   'knowledge',
#   'is',
#   'share',
#   'spaces',
#   'like',
#   'confluence',
#   'ms',
#   'team',
#   'are',
#   'great',
#   'tools',
#   'for',
#   'this'],
#  ['active', 'training'],
#  ['making',
#   'data',
#   'analytics',
#   'tools',
#   'available',
#   'to',
#   'all',
#   'departments',
#   'and',
#   'offering',
#   'training'],
#  ['more',
#   'exposure',
#   'to',
#   'new',
#   'technologies',
#   'that',
#   'drive',
#   'data',
#   'management',
#   'within',
#   'the',
#   'organization'],
#  ['training', 'training', 'and', 'more', 'training'],
#  ['visibility', 'on', 'comprehensive', 'level', 'and', 'roadshows'],
#  ['proved', 'to', 'be', 'useful', 'to', 'user', 'base'],
#  ['empower', 'all', 'employees', 'hold', 'people', 'responsible'],
#  [],
#  ['encourage', 'people', 'to', 'attend', 'more', 'analytical', 'trainings'],
#  ['read', 'up', 'on', 'it', 'and', 'implement', 'where', 'can'],
#  ['need', 'to', 'build', 'program', 'karen'],
#  ['constant', 'training', 'and', 'awareness'],
#  ['roadshows', 'colaboration', 'with', 'other', 'companies'],
#  ['will',
#   'send',
#   'people',
#   'to',
#   'training',
#   'and',
#   'then',
#   'investigate',
#   'what',
#   'technologies',
#   'will',
#   'provide'],
#  ['discuss', 'it', 'in', 'retros', 'and', 'dailies'],
#  ['the',
#   'everchanging',
#   'technology',
#   'streams',
#   'requires',
#   'investment',
#   'in',
#   'it',
#   'resources',
#   'such',
#   'as',
#   'people',
#   'and',
#   'hardware'],
#  ['have',
#   'clear',
#   'plan',
#   'for',
#   'data',
#   'driven',
#   'venture',
#   'then',
#   'meet',
#   'product',
#   'domains',
#   'face',
#   'to',
#   'face',
#   'sharing',
#   'the',
#   'strategy',
#   'and',
#   'roadmap',
#   'ask',
#   'for',
#   'input',
#   'then',
#   'show',
#   'funky',
#   'tools',
#   'and',
#   'immediate',
#   'results',
#   'in',
#   'human',
#   'visual',
#   'style',
#   'to',
#   'demonstrate',
#   'the',
#   'benefits',
#   'perhaps',
#   'from',
#   'product',
#   'confined',
#   'example'],
#  ['the',
#   'organisation',
#   'should',
#   'make',
#   'this',
#   'part',
#   'of',
#   'their',
#   'strategy',
#   'plan',
#   'and',
#   'indicate',
#   'this',
#   'in',
#   'their',
#   'year',
#   'roll',
#   'out',
#   'plan'],
#  ['open', 'day', 'and', 'training'],
#  ['forum', 'communication', 'day', 'to', 'explain', 'benefits'],
#  ['create', 'competency', 'centre'],
#  ['running',
#   'awareness',
#   'campaigns',
#   'surveys',
#   'to',
#   'find',
#   'out',
#   'what',
#   'the',
#   'peoples',
#   'current',
#   'knowledge',
#   'is',
#   'and',
#   'work',
#   'towards',
#   'improving',
#   'gaps',
#   'identified'],
#  ['better',
#   'availability',
#   'of',
#   'data',
#   'less',
#   'hoarding',
#   'of',
#   'data',
#   'sharing',
#   'is',
#   'caring',
#   'improve',
#   'knowledge',
#   'and',
#   'expertise',
#   'and',
#   'recognise',
#   'it',
#   'within',
#   'an',
#   'organization'],
#  ['keep', 'people', 'informed', 'every', 'step', 'of', 'the', 'process'],
#  ['by',
#   'attending',
#   'courses',
#   'to',
#   'understand',
#   'core',
#   'concepts',
#   'and',
#   'then',
#   'experiment',
#   'with',
#   'poc',
#   'proof',
#   'of',
#   'concepts',
#   'to',
#   'get',
#   'an',
#   'in',
#   'depth',
#   'understanding',
#   'of',
#   'methodologies',
#   'and',
#   'techniques'],
#  ['training', 'in', 'class', 'and', 'online'],
#  ['technology', 'training'],
#  ['send',
#   'people',
#   'to',
#   'do',
#   'certifications',
#   'of',
#   'qualifications',
#   'if',
#   'they',
#   'are',
#   'keen',
#   'to',
#   'do',
#   'it',
#   'like',
#   'aws',
#   'certification',
#   'or',
#   'university',
#   'degree'],
#  ['make', 'it', 'more', 'accessible'],
#  ['showcasing',
#   'advantage',
#   'have',
#   'specialist',
#   'spend',
#   'couple',
#   'sessions',
#   'with',
#   'executive',
#   'level',
#   'mng',
#   'while',
#   'also',
#   'assisting',
#   'the',
#   'operations',
#   'mng'],
#  ['improve',
#   'skills',
#   'by',
#   'adding',
#   'challenge',
#   'or',
#   'gamification',
#   'to',
#   'the',
#   'data',
#   'use',
#   'and',
#   'analysis',
#   'users',
#   'can',
#   'as',
#   'an',
#   'example',
#   'earn',
#   'badges',
#   'etc'],
#  ['create',
#   'regular',
#   'discussion',
#   'forums',
#   'with',
#   'specific',
#   'topics',
#   'within',
#   'the',
#   'data',
#   'domain',
#   'where',
#   'individuals',
#   'can',
#   'contribute',
#   'knowledge',
#   'gathered',
#   'from',
#   'experience',
#   'create',
#   'predictive',
#   'prescriptive',
#   'analytics',
#   'topic',
#   'for',
#   'discussion',
#   'where',
#   'interested',
#   'individuals',
#   'could',
#   'contribute',
#   'existing',
#   'or',
#   'new',
#   'ideas'],
#  ['getting', 'people', 'trained', 'on', 'new', 'technology'],
#  ['training', 'and', 'knowledge', 'sharing'],
#  ['knowledge',
#   'and',
#   'skills',
#   'are',
#   'mostly',
#   'obtained',
#   'through',
#   'experiences',
#   'having',
#   'concrete',
#   'goal',
#   'achieves',
#   'more',
#   'in',
#   'gaining',
#   'knowledge',
#   'than',
#   'learning',
#   'theoretical',
#   'concepts'],
#  ['create',
#   'exposure',
#   'and',
#   'understanding',
#   'of',
#   'the',
#   'value',
#   'added',
#   'by',
#   'data',
#   'driven',
#   'maturity'],
#  ['give',
#   'employees',
#   'the',
#   'chance',
#   'to',
#   'upskill',
#   'as',
#   'part',
#   'of',
#   'work',
#   'requirements',
#   'the',
#   'more',
#   'knowledge',
#   'we',
#   'have',
#   'the',
#   'better',
#   'for',
#   'the',
#   'organisation'],
#  ['knowledge', 'sharing', 'and', 'any', 'form', 'of', 'training'],
#  ['identify',
#   'strong',
#   'skills',
#   'and',
#   'hold',
#   'onto',
#   'them',
#   'identify',
#   'teams',
#   'depts',
#   'that',
#   'we',
#   'aligned',
#   'with',
#   'this',
#   'strategy',
#   'and',
#   'grow',
#   'them'],
#  [],
#  ['training', 'including', 'those', 'of', 'the', 'business', 'users'],
#  ['online', 'office', 'training', 'forums'],
#  ['provide',
#   'technology',
#   'days',
#   'to',
#   'raise',
#   'awareness',
#   'of',
#   'available',
#   'tools'],
#  ['my',
#   'upskilling',
#   'on',
#   'its',
#   'employees',
#   'and',
#   'moving',
#   'to',
#   'data',
#   'driven',
#   'technologies',
#   'to',
#   'support',
#   'the',
#   'data',
#   'analytics',
#   'strategy'],
#  ['on', 'site', 'and', 'online', 'training'],
#  ['training'],
#  ['training'],
#  ['expose', 'teams', 'to', 'different', 'technologies', 'to', 'use'],
#  ['training'],
#  ['have',
#   'basic',
#   'training',
#   'have',
#   'knowledge',
#   'sharing',
#   'sessions',
#   'show',
#   'examples',
#   'where',
#   'it',
#   'is',
#   'solving',
#   'problems'],
#  ['trainings', 'and', 'forums'],
#  ['training'],
#  ['compulsory',
#   'training',
#   'for',
#   'all',
#   'employees',
#   'online',
#   'workshops',
#   'etc',
#   'based',
#   'on',
#   'what',
#   'they',
#   'require',
#   'to',
#   'go',
#   'to',
#   'the',
#   'next',
#   'level'],
#  ['would',
#   'like',
#   'to',
#   'see',
#   'clear',
#   'expectations',
#   'from',
#   'the',
#   'company',
#   'as',
#   'developer',
#   'need',
#   'to',
#   'see',
#   'what',
#   'the',
#   'company',
#   'expects',
#   'from',
#   'me',
#   'then',
#   'could',
#   'work',
#   'towards',
#   'that',
#   'goal',
#   'and',
#   'if',
#   'need',
#   'be',
#   'enhance',
#   'my',
#   'skills'],
#  ['keep', 'empl', 'yees', 'think', 'forward'],
#  ['workshops',
#   'demo',
#   'sessions',
#   'unpacking',
#   'issues',
#   'at',
#   'the',
#   'core',
#   'first',
#   'then',
#   'applying',
#   'the',
#   'right',
#   'tools',
#   'to',
#   'gather',
#   'the',
#   'right',
#   'information',
#   'to',
#   'generate',
#   'the',
#   'insights',
#   'required',
#   'on',
#   'their',
#   'specific',
#   'projects'],
#  ['knowledge', 'sharing', 'sessions', 'sharing', 'success', 'stories'],
#  ['engage', 'employees', 'at', 'all', 'levels'],
#  ['have',
#   'seniors',
#   'and',
#   'juniors',
#   'work',
#   'more',
#   'closely',
#   'together',
#   'have',
#   'more',
#   'cross',
#   'polenation',
#   'of',
#   'environments',
#   'to',
#   'increase',
#   'diverse',
#   'knowledge',
#   'and',
#   'methods'],
#  ['having',
#   'tools',
#   'that',
#   'can',
#   'help',
#   'the',
#   'people',
#   'to',
#   'continually',
#   'improve'],
#  ['introduce', 'more', 'knowledge', 'sharing', 'sessions'],
#  ['dedicated',
#   'product',
#   'expert',
#   'that',
#   'pair',
#   'work',
#   'with',
#   'the',
#   'already',
#   'existing',
#   'teams',
#   'major',
#   'major',
#   'focus',
#   'is',
#   'on',
#   'communication',
#   'skills',
#   'ie',
#   'just',
#   'being',
#   'able',
#   'to',
#   'communicate',
#   'in',
#   'english'],
#  ['regular', 'internal', 'conferences', 'with', 'different', 'presenters'],
#  ['have', 'training', 'sessions'],
#  ['daily',
#   'exposure',
#   'to',
#   'data',
#   'and',
#   'analize',
#   'alignment',
#   'with',
#   'goals'],
#  ['provide',
#   'resourcing',
#   'for',
#   'training',
#   'time',
#   'and',
#   'training',
#   'materials'],
#  ['build',
#   'bmw',
#   'into',
#   'technology',
#   'company',
#   'combine',
#   'tesla',
#   'and',
#   'apple'],
#  ['exposing',
#   'people',
#   'to',
#   'new',
#   'technology',
#   'and',
#   'platforms',
#   'is',
#   'very',
#   'good',
#   'way',
#   'if',
#   'people',
#   'use',
#   'system',
#   'and',
#   'sees',
#   'the',
#   'benefits',
#   'they',
#   'will',
#   'buy',
#   'in',
#   'and',
#   'also',
#   'be',
#   'on',
#   'board'],
#  ['increase',
#   'the',
#   'employee',
#   'data',
#   'readiness',
#   'employees',
#   'users',
#   'must',
#   'use',
#   'the',
#   'systems'],
#  ['through', 'training', 'and', 'developer', 'pairing'],
#  ['short', 'training', 'videos'],
#  [],
#  ['training'],
#  ['create',
#   'opportunities',
#   'and',
#   'give',
#   'time',
#   'for',
#   'cross',
#   'skilling'],
#  ['identify', 'shortfalls', 'and', 'make', 'it', 'case', 'study'],
#  ['make',
#   'data',
#   'more',
#   'pervasive',
#   'in',
#   'management',
#   'reporting',
#   'and',
#   'the',
#   'skills',
#   'will',
#   'need',
#   'to',
#   'be',
#   'developed'],
#  ['increase', 'training', 'on', 'tools', 'and', 'tech'],
#  ['training',
#   'and',
#   'ensure',
#   'management',
#   'has',
#   'the',
#   'right',
#   'skills',
#   'and',
#   'knowledge',
#   'that',
#   'is',
#   'transferable'],
#  ['training',
#   'knowledge',
#   'sharing',
#   'events',
#   'knowledge',
#   'sharing',
#   'platforms',
#   'confluence',
#   'is',
#   'already',
#   'performing',
#   'this',
#   'role'],
#  ['already',
#   'promoting',
#   'the',
#   'product',
#   'so',
#   'not',
#   'much',
#   'more',
#   'to',
#   'be',
#   'done'],
#  ['diversity', 'in', 'skills', 'and', 'knowledge'],
#  ['temporarily',
#   'transfer',
#   'employees',
#   'between',
#   'environment',
#   'in',
#   'order',
#   'to',
#   'increase',
#   'exposure',
#   'to',
#   'multiple',
#   'platforms'],
#  ['more', 'workshops'],
#  ['self',
#   'learning',
#   'product',
#   'and',
#   'or',
#   'official',
#   'product',
#   'training'],
#  ['practical',
#   'and',
#   'realizable',
#   'applications',
#   'will',
#   'build',
#   'technical',
#   'experience',
#   'and',
#   'confidence',
#   'tailored',
#   'training',
#   'will',
#   'be',
#   'more',
#   'beneficial'],
#  ['bu', 'providing', 'trainings'],
#  ['have',
#   'knowledge',
#   'sharing',
#   'session',
#   'and',
#   'meetings',
#   'that',
#   'teams',
#   'can',
#   'share',
#   'new',
#   'data',
#   'platforms',
#   'they',
#   'are',
#   'using',
#   'and',
#   'what',
#   'is',
#   'the',
#   'positives',
#   'and',
#   'negatives',
#   'of',
#   'the',
#   'platforms'],
#  ['offer', 'trainings', 'and', 'workshops'],
#  ['towards',
#   'team',
#   'discussions',
#   'or',
#   'discussions',
#   'with',
#   'data',
#   'stuarts'],
#  ['training',
#   'and',
#   'internal',
#   'projects',
#   'poc',
#   'for',
#   'teams',
#   'to',
#   'work',
#   'on',
#   'innovations'],
#  ['upskill', 'people', 'and', 'update', 'technologies'],
#  ['in', 'house', 'training', 'focusing', 'on', 'data', 'driven', 'metrix'],
#  ['document',
#   'it',
#   'in',
#   'such',
#   'way',
#   'that',
#   'it',
#   'is',
#   'use',
#   'simple',
#   'and',
#   'usable',
#   'and',
#   'understandable'],
#  ['training'],
#  ['on',
#   'site',
#   'and',
#   'online',
#   'training',
#   'opportunity',
#   'to',
#   'use',
#   'data',
#   'driven',
#   'skills',
#   'even',
#   'if',
#   'the',
#   'skills',
#   'are',
#   'undeveloped',
#   'and',
#   'will',
#   'not',
#   'necessarily',
#   'result',
#   'in',
#   'much',
#   'utility',
#   'yet'],
#  ['communication'],
#  ['greater',
#   'exposure',
#   'to',
#   'an',
#   'even',
#   'wider',
#   'audience',
#   'not',
#   'to',
#   'just',
#   'those',
#   'that',
#   'are',
#   'tasked',
#   'to',
#   'build',
#   'applications'],
#  ['appoint', 'the', 'right', 'people'],
#  ['awareness', 'and', 'training'],
#  ['exposure', 'to', 'actual', 'implementations'],
#  ['by',
#   'ensuring',
#   'that',
#   'the',
#   'appropriate',
#   'people',
#   'attend',
#   'tailored',
#   'sessions',
#   'delivering',
#   'specific',
#   'knowledge',
#   'base',
#   'to',
#   'enable',
#   'individuals',
#   'to',
#   'be',
#   'able',
#   'to',
#   'grasp',
#   'the',
#   'concept',
#   'of',
#   'data',
#   'maturity',
#   'and',
#   'be',
#   'able',
#   'to',
#   'work',
#   'with',
#   'and',
#   'grow',
#   'during',
#   'the',
#   'data',
#   'journey',
#   'of',
#   'the',
#   'organization'],
#  ['have',
#   'more',
#   'knowledge',
#   'sharing',
#   'sessions',
#   'where',
#   'the',
#   'domain',
#   'experts',
#   'can',
#   'share',
#   'what',
#   'they',
#   're',
#   'already',
#   'learned',
#   'and',
#   'practiced'],
#  ['more', 'research', 'done', 'within', 'teams', 'and', 'workshops', 'held'],
#  ['training', 'general', 'awareness', 'sharing', 'articles', 'etc'],
#  ['training', 'in', 'technologies', 'used'],
#  ['online', 'training', 'sessions'],
#  ['encourage',
#   'up',
#   'skilling',
#   'in',
#   'data',
#   'driven',
#   'fields',
#   'of',
#   'choice',
#   'via',
#   'sponsored',
#   'training'],
#  ['training', 'workshops'],
#  ['ensuring', 'stakeholders', 'understand', 'their', 'data'],
#  ['training']]

# %%
data = [[0.5, 0.6],   
        [0.1, 0.8],
        [0.1, 0.8],
        [0.1, 0.8]]
ax = sns.heatmap(data)

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
uniform_data = np.random.rand(10, 12)

print(uniform_data)

ax = sns.heatmap(uniform_data)
# Out:
# [[0.5488135  0.71518937 0.60276338 0.54488318 0.4236548  0.64589411
#   0.43758721 0.891773   0.96366276 0.38344152 0.79172504 0.52889492]
#  [0.56804456 0.92559664 0.07103606 0.0871293  0.0202184  0.83261985
#   0.77815675 0.87001215 0.97861834 0.79915856 0.46147936 0.78052918]
#  [0.11827443 0.63992102 0.14335329 0.94466892 0.52184832 0.41466194
#   0.26455561 0.77423369 0.45615033 0.56843395 0.0187898  0.6176355 ]
#  [0.61209572 0.616934   0.94374808 0.6818203  0.3595079  0.43703195
#   0.6976312  0.06022547 0.66676672 0.67063787 0.21038256 0.1289263 ]
#  [0.31542835 0.36371077 0.57019677 0.43860151 0.98837384 0.10204481
#   0.20887676 0.16130952 0.65310833 0.2532916  0.46631077 0.24442559]
#  [0.15896958 0.11037514 0.65632959 0.13818295 0.19658236 0.36872517
#   0.82099323 0.09710128 0.83794491 0.09609841 0.97645947 0.4686512 ]
#  [0.97676109 0.60484552 0.73926358 0.03918779 0.28280696 0.12019656
#   0.2961402  0.11872772 0.31798318 0.41426299 0.0641475  0.69247212]
#  [0.56660145 0.26538949 0.52324805 0.09394051 0.5759465  0.9292962
#   0.31856895 0.66741038 0.13179786 0.7163272  0.28940609 0.18319136]
#  [0.58651293 0.02010755 0.82894003 0.00469548 0.67781654 0.27000797
#   0.73519402 0.96218855 0.24875314 0.57615733 0.59204193 0.57225191]
#  [0.22308163 0.95274901 0.44712538 0.84640867 0.69947928 0.29743695
#   0.81379782 0.39650574 0.8811032  0.58127287 0.88173536 0.69253159]]

# %%
# Python code demonstrate creating
# pandas DataFrame with indexed by
 
# DataFrame using arrays.
import pandas as pd
 
# initialise data of lists.
data = {'Knowledge 1':[99, 98, 95, 90],
        'Knowledge 2':[99, 98, 95, 90]}
 
# Creates pandas DataFrame.
df = pd.DataFrame(data, index =['Word1',
                                'Word2',
                                'Word3',
                                'word4'])
 
# print the data
df
# Out:
#        Knowledge 1  Knowledge 2
# Word1           99           99
# Word2           98           98
# Word3           95           95
# word4           90           90

# %%
ax = sns.heatmap(df)
